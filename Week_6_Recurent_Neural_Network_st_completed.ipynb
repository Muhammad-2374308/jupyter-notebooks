# %% [markdown]
# <html> <h1 style="font-style:bold; color:blue;"> Neural Computing and Deep Learning </h1> </html>

# %% [markdown]
# <html> <h1 style="font-style:italic; color:blue;"> Week-6 </h1> </html>

# %% [markdown]
# <html> <h2 style="font-style:italic; color:blue;"> RNN for Time Series </h2> </html>
#
#
# RNNs are used for sequence modelling. This tutorial will look at time series data to be modelled and predicted using RNNs.

# %%
# Import Libraries (pandas, numpy, matplotlib)

import pandas as pd 
import numpy as np
# %matplotlib inline 
import matplotlib.pyplot as plt

# %% [markdown]
# ### Data
#
# We will use retail data for time-series modeling.
#
# Link to the dataset:
#  https://fred.stlouisfed.org/series/MRTSSM448USN
#
# Information about the Advance Monthly Retail Sales Survey can be found on the Census website at:
# https://www.census.gov/retail/marts/about_the_surveys.html
#
# Release: Advance Monthly Sales for Retail and Food Services
# Units:  Millions of Dollars, Not Seasonally Adjusted
# Frequency:  Monthly
#
# Suggested Citation:
# U.S. Census Bureau, Advance Retail Sales: Clothing and Clothing Accessory Stores [RSCCASN], retrieved from FRED, Federal Reserve Bank of St. Louis; https://fred.stlouisfed.org/series/RSCCASN, January 25, 2025.

# %% [markdown]
# ##### Read data first -  Use index_col = 'DATE' and 'parse_dates = True' as a parameter.

# %% [markdown]
# _________________![image.png](attachment:d2f728cb-4c14-4ede-9ca4-3210197b3bf5.png)

# %%
df = pd.read_csv('MRTSSM448USN_24.csv',index_col='observation_date', parse_dates=True)

# %%
#pd.read_csv

# %%
# Print the first few rows of data
#d
# ...

# %%
df.head()
# Out:
#                   MRTSSM448USN
# observation_date
# 1992-01-01                6938
# 1992-02-01                7524
# 1992-03-01                8475
# 1992-04-01                9401
# 1992-05-01                9558

# %%
# Out:
#                   MRTSSM448USN
# observation_date
# 1992-01-01                6938
# 1992-02-01                7524
# 1992-03-01                8475
# 1992-04-01                9401
# 1992-05-01                9558

# %% [markdown]
# _______________![image.png](attachment:7e472928-25f6-4701-891d-d6e138d8301c.png)

# %%
df.tail()
# Out:
#                   MRTSSM448USN
# observation_date
# 2024-08-01               27215
# 2024-09-01               23088
# 2024-10-01               25318
# 2024-11-01               29762
# 2024-12-01               41199

# %%
# Out:
#                   MRTSSM448USN
# observation_date
# 2024-08-01               27215
# 2024-09-01               23088
# 2024-10-01               25318
# 2024-11-01               29762
# 2024-12-01               41199

# %% [markdown]
# Does the sales column has any name?
#
# If no, set the name of the colum as 'Sales'.

# %%
# Set name of column as 'Sales'. Use - df.columns 

df.columns = ['Sales']
df.head()
# Out:
#                   Sales
# observation_date
# 1992-01-01         6938
# 1992-02-01         7524
# 1992-03-01         8475
# 1992-04-01         9401
# 1992-05-01         9558

# %%
# Out:
#                   Sales
# observation_date
# 1992-01-01         6938
# 1992-02-01         7524
# 1992-03-01         8475
# 1992-04-01         9401
# 1992-05-01         9558

# %% [markdown]
# Plot your data - Year vs Sales
#
# hint: use df.plot  and plt.show()

# %% [markdown]
# ____________![image.png](attachment:805024e0-d954-465a-b7e2-ddfb909885ff.png)

# %%
df.plot(figsize=(12,9))
# Out:
# <Axes: xlabel='observation_date'>

# %% [markdown]
# ### Train Test Split
#
# We will use the last 1.5 years (18 months) samples for testing. The rest is for training

# %% [markdown]
# ______________![image.png](attachment:e38848db-d649-4cf7-a213-65b7f4afb347.png)

# %%
test_size = 18
test_size
# Out:
# 18

# %%
# Out:
# 18

# %% [markdown]
# __________![image.png](attachment:2c857cf3-2515-4517-9d3d-db350c691bf7.png)

# %%
data_length = len(df)
data_length
# Out:
# 396

# %%
# Out:
# 396

# %% [markdown]
# __________________![image.png](attachment:f8eaa367-9088-41f8-8b8b-9d268a0818ed.png)

# %%
train_size = data_length- test_size
train_size
# Out:
# 378

# %%
# Out:
# 378

# %% [markdown]
# Now, we will find the indexes of the test data. Remember, these are the last 18 indexes in the pandas dataframe.

# %% [markdown]
# ____________________![image.png](attachment:91a08444-364a-40fa-a0c3-839197c15995.png)

# %%
test_index = train_size
test_index
# Out:
# 378

# %%
# Out:
# 378

# %% [markdown]
# Next, we will separate train and test datasets.

# %% [markdown]
# _________________________![image.png](attachment:3ae07221-155f-4716-9ea4-7484eb94dab4.png)

# %%
train = df.iloc[:test_index]
train
# Out:
#                   Sales
# observation_date
# 1992-01-01         6938
# 1992-02-01         7524
# 1992-03-01         8475
# 1992-04-01         9401
# 1992-05-01         9558
# ...                 ...
# 2023-02-01        20666
# 2023-03-01        24510
# 2023-04-01        24232
# 2023-05-01        26096
# 2023-06-01        24364
#
# [378 rows x 1 columns]

# %%
# Out:
#                   Sales
# observation_date
# 1992-01-01         6938
# 1992-02-01         7524
# 1992-03-01         8475
# 1992-04-01         9401
# 1992-05-01         9558
# ...                 ...
# 2023-02-01        20666
# 2023-03-01        24510
# 2023-04-01        24232
# 2023-05-01        26096
# 2023-06-01        24364
#
# [378 rows x 1 columns]

# %%
# Store everything from test_index to the last sample in the test variable 
# Hint - Use df.iloc

# ...
# ...
test = df.iloc[test_index:]
test
# Out:
#                   Sales
# observation_date
# 2023-07-01        24911
# 2023-08-01        26657
# 2023-09-01        23332
# 2023-10-01        23933
# 2023-11-01        28580
# 2023-12-01        40684
# 2024-01-01        19188
# 2024-02-01        22005
# 2024-03-01        24986
# 2024-04-01        23993
# 2024-05-01        27562
# 2024-06-01        25121
# 2024-07-01        25453
# 2024-08-01        27215
# 2024-09-01        23088
# 2024-10-01        25318
# 2024-11-01        29762
# 2024-12-01        41199

# %%
# Out:
#                   Sales
# observation_date
# 2023-07-01        24911
# 2023-08-01        26657
# 2023-09-01        23332
# 2023-10-01        23933
# 2023-11-01        28580
# 2023-12-01        40684
# 2024-01-01        19188
# 2024-02-01        22005
# 2024-03-01        24986
# 2024-04-01        23993
# 2024-05-01        27562
# 2024-06-01        25121
# 2024-07-01        25453
# 2024-08-01        27215
# 2024-09-01        23088
# 2024-10-01        25318
# 2024-11-01        29762
# 2024-12-01        41199

# %%
# Print the size of the train data

print(train.shape)

# Print the size of the test data
print(test.shape)
# Out:
# (378, 1)
# (18, 1)

# %%
# Out:
# 378
# 18

# %% [markdown]
# ### In Neural Networks, we need to Scale Data between 0-1

# %% [markdown]
# ___________________![image.png](attachment:427170b6-570a-4740-b005-cd2e88a0f8b6.png)

# %%
from sklearn.preprocessing import MinMaxScaler

# %% [markdown]
# _______________________![image.png](attachment:b5ef2c4e-c013-4af5-9320-c48c58751458.png)

# %%
scaler = MinMaxScaler()
scaler.fit(train)
# Out:
# MinMaxScaler()

# %%
# Out:
# MinMaxScaler()

# %% [markdown]
# __________________![image.png](attachment:4e64d75b-6582-4975-bd2f-3881d943301d.png)

# %%
scaled_train = scaler.transform(train)
scaled_test = scaler.transform(test)

# %%
# Check if the data has been scaled properly
# Print max and min for train and test

print(scaled_train.max())
print(scaled_test.max())
print(scaled_train.min())
print(scaled_test.min())
# Out:
# 1.0
# 1.0530599939704552
# 0.0
# 0.44980403979499545

# %%
# Out:
# 1.0
# 1.0530599939704552
# 0.0
# 0.44980403979499545

# %% [markdown]
# ## Time Series Generator
#
# This class takes in a sequence of data points gathered at
# equal intervals, along with time series parameters such as
# stride, length of history, etc., to produce batches for
# training/validation.
#
# #### Arguments
#     data: Indexable generator (such as list or Numpy array)
#         containing consecutive data points (timesteps).
#         The data should be at 2D, and axis 0 is expected
#         to be the time dimension.
#     targets: Targets corresponding to timesteps in `data`.
#         It should have same length as `data`.
#     length: Length of the output sequences (in number of timesteps).
#     sampling_rate: Period between successive individual timesteps
#         within sequences. For rate `r`, timesteps
#         `data[i]`, `data[i-r]`, ... `data[i - length]`
#         are used for create a sample sequence.
#     stride: Period between successive output sequences.
#         For stride `s`, consecutive output samples would
#         be centered around `data[i]`, `data[i+s]`, `data[i+2*s]`, etc.
#     start_index: Data points earlier than `start_index` will not be used
#         in the output sequences. This is useful to reserve part of the
#         data for test or validation.
#     end_index: Data points later than `end_index` will not be used
#         in the output sequences. This is useful to reserve part of the
#         data for test or validation.
#     shuffle: Whether to shuffle output samples,
#         or instead draw them in chronological order.
#     reverse: Boolean: if `true`, timesteps in each output sample will be
#         in reverse chronological order.
#     batch_size: Number of timeseries samples in each batch
#         (except maybe the last one).

# %% [markdown]
# ### We will use 12 months as input and then predict the next month out

# %% [markdown]
# _____________________![image.png](attachment:75eeec67-065a-4084-9a2b-c10207e20cba.png)

# %%
from tensorflow.keras.preprocessing.sequence import TimeseriesGenerator

# %%
#TimeseriesGenerator?

# %% [markdown]
# _________________![image.png](attachment:280feffa-2228-4562-9b29-005f579078ef.png)

# %%
length = 12 
generator = TimeseriesGenerator(scaled_train, scaled_train, length=length, batch_size=1)

# %% [markdown]
# _______________________![image.png](attachment:6525f6be-465f-4f4c-8198-cad63a006c9b.png)

# %%
X, y =generator [0]
print(f'given the Array: \n {X.flatten()}')
print(f'Predict this y: \n {y}')
# Out:
# given the Array:
#  [0.11406802 0.13012854 0.15619262 0.18157152 0.18587442 0.17556938
#  0.17340423 0.21204813 0.18628553 0.20494971 0.23052046 0.42807027]
# Predict this y:
#  [[0.12952558]]

# %%
# Out:
# Given the Array:
# [0.11406802 0.13012854 0.15619262 0.18157152 0.18587442 0.17556938
#  0.17340423 0.21204813 0.18628553 0.20494971 0.23052046 0.42807027]
# Predict this y:
#  [[0.12952558]]

# %% [markdown]
# ### Create the Model

# %% [markdown]
# <html> <h4 style="font-style:italic; color:blue;"> Just run the next cell using 'Ctrl' + 'Enter' </h4> </html>

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense
from tensorflow.keras.layers import LSTM
from tensorflow.keras.layers import SimpleRNN
from tensorflow.keras.layers import GRU

import tensorflow as tf

# %% [markdown]
# ________________![image.png](attachment:aef51a9d-f017-45c3-a12d-2a77630a3721.png)

# %%
n_features = 1
n_features
# Out:
# 1

# %%
# Out:
# 1

# %% [markdown]
# ## Define your own models.
#
# Use 1. SimpleRNN, LSTM, or GRU neural network.
#
# APIs:
# https://keras.io/api/layers/recurrent_layers/

# %%
# Your code to create your own model
# use input_shape=(length, n_features)
# use model.add(Dense(1)) because it is the regression 
model = Sequential()
model.add(LSTM(14, activation='relu', input_shape=(length, n_features)))
model.add(Dense(1))
# Out:
# C:\Users\Chani\anaconda3\Lib\site-packages\keras\src\layers\rnn\rnn.py:200: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)

# %% [markdown]
# <html> <h4 style="font-style:italic; color:blue;"> Just run the next cell using 'Ctrl' + 'Enter' </h4> </html>

# %%
model.summary()
# Out:
# Model: "sequential_4"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ lstm_4 (LSTM)                   │ (None, 14)             │           896 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_4 (Dense)                 │ (None, 1)              │            15 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 911 (3.56 KB)
#  Trainable params: 911 (3.56 KB)
#  Non-trainable params: 0 (0.00 B)

# %% [markdown]
# _____________________![image.png](attachment:5f040382-1621-443b-87a6-48ad7c9c995f.png)

# %%
model.compile(optimizer='adam', loss='mse')

# %% [markdown]
# ### EarlyStopping and creating a Validation Generator
#
# NOTE: The scaled_test dataset size MUST be greater than your length chosen for your batches.
#
# Review the video on the Week-6 page for more info on this.

# %% [markdown]
# <html> <h4 style="font-style:italic; color:blue;"> Just run the 2 next cells using 'Ctrl' + 'Enter' </h4> </html>

# %%
validation_generator = TimeseriesGenerator(scaled_test, scaled_test, 
                                            length=length, batch_size=1)

# %%
from tensorflow.keras.callbacks import EarlyStopping

# %%
# Your code to create an object early-stop

# Use the patience parameter equal to the last digit in your SID.
# If the last digit of your SID = 0, then assign patience=10
# For example, your SID = 22984879, then patience=9

# LAST_DIGIT_IN_YOUR_SID = 

early_stop = EarlyStopping(monitor='val_loss',patience=3)

# %% [markdown]
# _____________________![image.png](attachment:e0ecd664-7df5-4386-a700-adb2228bf254.png)

# %%
history = model.fit(generator, epochs=10,
                    validation_data=validation_generator,
                    callbacks=[early_stop])
# Out:
# Epoch 1/10
# C:\Users\Chani\anaconda3\Lib\site-packages\keras\src\trainers\data_adapters\py_dataset_adapter.py:121: UserWarning: Your `PyDataset` class should call `super().__init__(**kwargs)` in its constructor. `**kwargs` can include `workers`, `use_multiprocessing`, `max_queue_size`. Do not pass these arguments to `fit()`, as they will be ignored.
#   self._warn_if_super_not_called()
# 366/366 ━━━━━━━━━━━━━━━━━━━━ 6s 7ms/step - loss: 0.0698 - val_loss: 0.0393
# Epoch 2/10
# 366/366 ━━━━━━━━━━━━━━━━━━━━ 3s 7ms/step - loss: 0.0127 - val_loss: 0.0304
# Epoch 3/10
# 366/366 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - loss: 0.0139 - val_loss: 0.0312
# Epoch 4/10
# 366/366 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - loss: 0.0141 - val_loss: 0.0234
# Epoch 5/10
# 366/366 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - loss: 0.0114 - val_loss: 0.0238
# Epoch 6/10
# 366/366 ━━━━━━━━━━━━━━━━━━━━ 3s 7ms/step - loss: 0.0136 - val_loss: 0.0143
# Epoch 7/10
# 366/366 ━━━━━━━━━━━━━━━━━━━━ 2s 6ms/step - loss: 0.0088 - val_loss: 0.0375
# Epoch 8/10
# 366/366 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - loss: 0.0103 - val_loss: 0.0059
# Epoch 9/10
# 366/366 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - loss: 0.0092 - val_loss: 0.0024
# Epoch 10/10
# 366/366 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - loss: 0.0070 - val_loss: 0.0075

# %%
# Out:
# C:\Users\vital\anaconda3\Lib\site-packages\keras\src\trainers\data_adapters\py_dataset_adapter.py:121: UserWarning: Your `PyDataset` class should call `super().__init__(**kwargs)` in its constructor. `**kwargs` can include `workers`, `use_multiprocessing`, `max_queue_size`. Do not pass these arguments to `fit()`, as they will be ignored.
#   self._warn_if_super_not_called()
# Epoch 1/30
# 366/366 ━━━━━━━━━━━━━━━━━━━━ 16s 22ms/step - loss: 0.0364 - val_loss: 0.0283
# Epoch 2/30
# 366/366 ━━━━━━━━━━━━━━━━━━━━ 6s 15ms/step - loss: 0.0124 - val_loss: 0.0153
# Epoch 3/30
# 366/366 ━━━━━━━━━━━━━━━━━━━━ 5s 15ms/step - loss: 0.0118 - val_loss: 0.0010
# Epoch 4/30
# 366/366 ━━━━━━━━━━━━━━━━━━━━ 7s 20ms/step - loss: 0.0068 - val_loss: 0.0032
# Epoch 5/30
# 366/366 ━━━━━━━━━━━━━━━━━━━━ 7s 18ms/step - loss: 0.0047 - val_loss: 0.0127
# Epoch 6/30
# 366/366 ━━━━━━━━━━━━━━━━━━━━ 7s 17ms/step - loss: 0.0079 - val_loss: 0.0011
# Epoch 7/30
# 366/366 ━━━━━━━━━━━━━━━━━━━━ 6s 15ms/step - loss: 0.0037 - val_loss: 0.0011
# Epoch 8/30
# 366/366 ━━━━━━━━━━━━━━━━━━━━ 6s 16ms/step - loss: 0.0043 - val_loss: 0.0015
# Epoch 9/30
# 366/366 ━━━━━━━━━━━━━━━━━━━━ 6s 15ms/step - loss: 0.0046 - val_loss: 0.0026
# Epoch 10/30
# 366/366 ━━━━━━━━━━━━━━━━━━━━ 5s 14ms/step - loss: 0.0042 - val_loss: 6.1039e-04
# Epoch 11/30
# 366/366 ━━━━━━━━━━━━━━━━━━━━ 7s 19ms/step - loss: 0.0049 - val_loss: 6.4973e-04
# Epoch 12/30
# 366/366 ━━━━━━━━━━━━━━━━━━━━ 7s 18ms/step - loss: 0.0033 - val_loss: 6.5717e-04
# Epoch 13/30
# 366/366 ━━━━━━━━━━━━━━━━━━━━ 6s 16ms/step - loss: 0.0031 - val_loss: 0.0065
# Epoch 14/30
# 366/366 ━━━━━━━━━━━━━━━━━━━━ 6s 15ms/step - loss: 0.0042 - val_loss: 0.0013
# Epoch 15/30
# 366/366 ━━━━━━━━━━━━━━━━━━━━ 6s 16ms/step - loss: 0.0040 - val_loss: 0.0025
# Epoch 16/30
# 366/366 ━━━━━━━━━━━━━━━━━━━━ 6s 16ms/step - loss: 0.0035 - val_loss: 0.0023
# Epoch 17/30
# 366/366 ━━━━━━━━━━━━━━━━━━━━ 6s 15ms/step - loss: 0.0026 - val_loss: 8.7657e-04
# Epoch 18/30
# 366/366 ━━━━━━━━━━━━━━━━━━━━ 6s 15ms/step - loss: 0.0045 - val_loss: 8.2289e-04

# %% [markdown]
# _____________![image.png](attachment:00bc3c6b-8d83-4d5c-80cc-1f586fc18bb3.png)

# %%
losses = pd.DataFrame(model.history.history)
losses[:5]
# Out:
#        loss  val_loss
# 0  0.032791  0.039349
# 1  0.014214  0.030375
# 2  0.014098  0.031211
# 3  0.013543  0.023440
# 4  0.012613  0.023761

# %%
# the values may be different
# Out:
#        loss  val_loss
# 0  0.020090  0.028262
# 1  0.012648  0.015266
# 2  0.010198  0.001036
# 3  0.006880  0.003225
# 4  0.005237  0.012703

# %% [markdown]
# ___________________![image.png](attachment:f4e5651a-8770-46d6-80cd-ad7c715e6fe4.png)

# %%
losses.plot()
plt.show();

# %% [markdown]
# <html> <h4 style="font-style:italic; color:blue;"> Just run the next cell using 'Ctrl' + 'Enter' </h4> </html>

# %%
# print Loss for the neural network training process

history_dict = history.history

acc_values = history_dict['loss']
val_acc_values = history_dict['val_loss']
epochs = range(1, len(acc_values) + 1)

plt.figure(num=1, figsize=(15,7))
plt.plot(epochs, acc_values, 'bo', label='Training loss')
plt.plot(epochs, val_acc_values, 'b', label='Validation loss')
plt.xlabel('Epochs')
plt.ylabel('Loss (mse)')
plt.legend()

plt.show()

# %% [markdown]
# ### Evaluate on Test Data

# %% [markdown]
# ____________________![image.png](attachment:78ee4976-41bd-457c-8de2-ee2446e02523.png)

# %%
print(scaled_train[-15:])
# Out:
# [[0.61523282]
#  [0.64077617]
#  [0.5909502 ]
#  [0.59621235]
#  [0.62693562]
#  [0.55844547]
#  [0.58834653]
#  [0.69254803]
#  [1.        ]
#  [0.44788555]
#  [0.49031162]
#  [0.59566421]
#  [0.58804506]
#  [0.63913175]
#  [0.59166278]]

# %%
# Out:
# [[0.61523282]
#  [0.64077617]
#  [0.5909502 ]
#  [0.59621235]
#  [0.62693562]
#  [0.55844547]
#  [0.58834653]
#  [0.69254803]
#  [1.        ]
#  [0.44788555]
#  [0.49031162]
#  [0.59566421]
#  [0.58804506]
#  [0.63913175]
#  [0.59166278]]

# %% [markdown]
# ____________________![image.png](attachment:7c5efeb5-4631-462d-b593-f7ee0b22b63b.png)

# %%
first_eval_batch = scaled_train[-length:]
first_eval_batch
# Out:
# array([[0.59621235],
#        [0.62693562],
#        [0.55844547],
#        [0.58834653],
#        [0.69254803],
#        [1.        ],
#        [0.44788555],
#        [0.49031162],
#        [0.59566421],
#        [0.58804506],
#        [0.63913175],
#        [0.59166278]])

# %%
# Out:
# array([[0.59621235],
#        [0.62693562],
#        [0.55844547],
#        [0.58834653],
#        [0.69254803],
#        [1.        ],
#        [0.44788555],
#        [0.49031162],
#        [0.59566421],
#        [0.58804506],
#        [0.63913175],
#        [0.59166278]])

# %% [markdown]
# <html> <h4 style="font-style:italic; color:blue;"> Just run the next cell using 'Ctrl' + 'Enter' </h4> </html>

# %%
n_input = 12
first_eval_batch = first_eval_batch.reshape((1, n_input, n_features))
first_eval_batch
# Out:
# array([[[0.59621235],
#         [0.62693562],
#         [0.55844547],
#         [0.58834653],
#         [0.69254803],
#         [1.        ],
#         [0.44788555],
#         [0.49031162],
#         [0.59566421],
#         [0.58804506],
#         [0.63913175],
#         [0.59166278]]])

# %% [markdown]
# ___________________![image.png](attachment:a2b037af-2ff0-42ce-9234-7ee8a9abb742.png)

# %%
model.predict(first_eval_batch)
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 308ms/step
# array([[0.6613139]], dtype=float32)

# %%
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 802ms/step
# array([[0.63285655]], dtype=float32)

# %% [markdown]
# _________________![image.png](attachment:b5adbbdd-43ed-4ee2-9417-382a709986b5.png)

# %%
scaled_test[0]
# Out:
# array([0.60665442])

# %%
# Out:
# array([0.60665442])

# %% [markdown]
# #### Try predicting the series!

# %% [markdown]
# <html> <h4 style="font-style:italic; color:blue;"> Just run the 3 next cells using 'Ctrl' + 'Enter' </h4> </html>

# %%
test_predictions = []

first_eval_batch = scaled_train[-length:]
current_batch = first_eval_batch.reshape((1, length, n_features))

current_batch
# Out:
# array([[[0.59621235],
#         [0.62693562],
#         [0.55844547],
#         [0.58834653],
#         [0.69254803],
#         [1.        ],
#         [0.44788555],
#         [0.49031162],
#         [0.59566421],
#         [0.58804506],
#         [0.63913175],
#         [0.59166278]]])

# %%
for i in range(len(test)):
    
    # get prediction 1 time stamp ahead ([0] is for 
    # grabbing just the number instead of [array])
    current_pred = model.predict(current_batch)[0]
    
    # store prediction
    test_predictions.append(current_pred) 
    
    # update batch to now include prediction and drop first value
    current_batch = np.append(current_batch[:,1:,:],[[current_pred]],axis=1)
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 75ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 65ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 53ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 89ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 89ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step

# %%
test_predictions
# Out:
# [array([0.6613139], dtype=float32),
#  array([0.6881987], dtype=float32),
#  array([0.6566504], dtype=float32),
#  array([0.679739], dtype=float32),
#  array([0.8637595], dtype=float32),
#  array([1.0446267], dtype=float32),
#  array([0.57893896], dtype=float32),
#  array([0.6175492], dtype=float32),
#  array([0.69275445], dtype=float32),
#  array([0.70522094], dtype=float32),
#  array([0.75673175], dtype=float32),
#  array([0.7448375], dtype=float32),
#  array([0.81239516], dtype=float32),
#  array([0.8525507], dtype=float32),
#  array([0.846304], dtype=float32),
#  array([0.89998764], dtype=float32),
#  array([1.1200534], dtype=float32),
#  array([1.3449637], dtype=float32)]

# %% [markdown]
# ### Inverse Transformations and Compare

# %% [markdown]
# _________________![image.png](attachment:9266da43-7b93-47a6-b135-724c546cf46b.png)

# %%
true_predictions= scaler.inverse_transform(test_predictions)
true_predictions
# Out:
# array([[26905.35995591],
#        [27886.30544317],
#        [26735.20402062],
#        [27577.6368351 ],
#        [34291.99352121],
#        [40891.2948699 ],
#        [23899.74587107],
#        [25308.51696658],
#        [28052.53152448],
#        [28507.39635491],
#        [30386.87131047],
#        [29952.8866837 ],
#        [32417.86203617],
#        [33883.0168584 ],
#        [33655.09402698],
#        [35613.84894758],
#        [43643.38879001],
#        [51849.68941915]])

# %%
# Out:
# array([[25867.03686076],
#        [26708.37140393],
#        [25016.20063967],
#        [25854.56223851],
#        [29340.47320271],
#        [40268.42497611],
#        [20830.97139931],
#        [22252.6564256 ],
#        [25053.23304337],
#        [25580.6207518 ],
#        [27142.1950959 ],
#        [26136.75054663],
#        [27203.31552541],
#        [27836.48089719],
#        [26630.20928335],
#        [27364.5308798 ],
#        [30701.01822633],
#        [41377.06135786]])

# %% [markdown]
# _____________![image.png](attachment:1689e362-0bac-4c6c-a993-55ff6789ceb7.png)

# %%
test['Prediction'] = true_predictions
# Out:
# C:\Users\Chani\AppData\Local\Temp\ipykernel_10580\168099314.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   test['Prediction'] = true_predictions

# %%
# Out:
# C:\Users\vital\AppData\Local\Temp\ipykernel_18288\3095654106.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   test['Predictions'] = true_predictions

# %% [markdown]
# ### Check and plot predictions

# %%
# Print the test variable

print(test)
# Out:
#                   Sales    Prediction
# observation_date
# 2023-07-01        24911  26905.359956
# 2023-08-01        26657  27886.305443
# 2023-09-01        23332  26735.204021
# 2023-10-01        23933  27577.636835
# 2023-11-01        28580  34291.993521
# 2023-12-01        40684  40891.294870
# 2024-01-01        19188  23899.745871
# 2024-02-01        22005  25308.516967
# 2024-03-01        24986  28052.531524
# 2024-04-01        23993  28507.396355
# 2024-05-01        27562  30386.871310
# 2024-06-01        25121  29952.886684
# 2024-07-01        25453  32417.862036
# 2024-08-01        27215  33883.016858
# 2024-09-01        23088  33655.094027
# 2024-10-01        25318  35613.848948
# 2024-11-01        29762  43643.388790
# 2024-12-01        41199  51849.689419

# %%
# Out:
#                   Sales   Predictions
# observation_date
# 2023-07-01        24911  25867.036861
# 2023-08-01        26657  26708.371404
# 2023-09-01        23332  25016.200640
# 2023-10-01        23933  25854.562239
# 2023-11-01        28580  29340.473203
# 2023-12-01        40684  40268.424976
# 2024-01-01        19188  20830.971399
# 2024-02-01        22005  22252.656426
# 2024-03-01        24986  25053.233043
# 2024-04-01        23993  25580.620752
# 2024-05-01        27562  27142.195096
# 2024-06-01        25121  26136.750547
# 2024-07-01        25453  27203.315525
# 2024-08-01        27215  27836.480897
# 2024-09-01        23088  26630.209283
# 2024-10-01        25318  27364.530880
# 2024-11-01        29762  30701.018226
# 2024-12-01        41199  41377.061358

# %% [markdown]
# _______________![image.png](attachment:f62685ae-fe3d-45e4-b14c-32c3f876ee6c.png)

# %%
test.plot(figsize=(8,5))
plt.show()

# %% [markdown]
# ### Retrain and Forecasting

# %% [markdown]
# <html> <h4 style="font-style:italic; color:blue;"> Just run the 3 next cells using 'Ctrl' + 'Enter' </h4> </html>

# %%
full_scaler = MinMaxScaler()
scaled_full_data = full_scaler.fit_transform(df)

# %%
print(scaled_full_data.max())
print(scaled_full_data.min())
# Out:
# 1.0
# 0.0

# %%
length = 12 # Length of the output sequences (in number of timesteps)
generator = TimeseriesGenerator(scaled_full_data, 
                                scaled_full_data, length=length, batch_size=1)

# %%
# Use any neural network model based on RNN
# You can also use the model created above
#
# Create the model
model = Sequential()
model.add(SimpleRNN(15, activation='relu', input_shape=(length, n_features)))
model.add(Dense(1))
# Out:
# C:\Users\Chani\anaconda3\Lib\site-packages\keras\src\layers\rnn\rnn.py:200: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)

# %%
# Out:
# C:\Users\vital\anaconda3\Lib\site-packages\keras\src\layers\rnn\rnn.py:204: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)

# %% [markdown]
# <html> <h4 style="font-style:italic; color:blue;"> Just run the next cell using 'Ctrl' + 'Enter' </h4> </html>

# %%
model.summary()
# Out:
# Model: "sequential_6"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ simple_rnn_1 (SimpleRNN)        │ (None, 15)             │           255 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_6 (Dense)                 │ (None, 1)              │            16 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 271 (1.06 KB)
#  Trainable params: 271 (1.06 KB)
#  Non-trainable params: 0 (0.00 B)

# %%
# your code to compile the model

# ...

# %%
model.compile(optimizer='adam', loss='mse')

# %%
# Your code to create an object early-stop

# Use the patience parameter equal to the last digit in your SID.
# If the last digit of your SID = 0, then assign patience=10
# For example, your SID = 22984879, then patience=9

# LAST_DIGIT_IN_YOUR_SID = 

early_stop = EarlyStopping(monitor='val_loss',patience=3)

# %% [markdown]
# ____________________![image.png](attachment:7b5b9107-f77e-4327-a987-878819f2ce45.png)

# %%
# fit the model

history_2 =  model.fit(generator,  epochs=10,
                    validation_data=validation_generator,
                    callbacks=[early_stop])
# Out:
# Epoch 1/10
# 384/384 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.0016 - val_loss: 0.0013
# Epoch 2/10
# 384/384 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 0.0015 - val_loss: 0.0025
# Epoch 3/10
# 384/384 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.0016 - val_loss: 0.0011
# Epoch 4/10
# 384/384 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.0020 - val_loss: 0.0023
# Epoch 5/10
# 384/384 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.0023 - val_loss: 5.6011e-04
# Epoch 6/10
# 384/384 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - loss: 0.0013 - val_loss: 0.0015
# Epoch 7/10
# 384/384 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - loss: 0.0016 - val_loss: 0.0019
# Epoch 8/10
# 384/384 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - loss: 0.0019 - val_loss: 0.0024

# %% [markdown]
# <html> <h4 style="font-style:italic; color:blue;"> Just run the next cell using 'Ctrl' + 'Enter' </h4> </html>

# %%
# print Loss for the neural network training process

history_dict = history_2.history

acc_values = history_dict['loss']
val_acc_values = history_dict['val_loss']
epochs = range(1, len(acc_values) + 1)

plt.figure(num=1, figsize=(15,7))
plt.plot(epochs, acc_values, 'bo', label='Training loss')
plt.plot(epochs, val_acc_values, 'b', label='Validation loss')
plt.xlabel('Epochs')
plt.ylabel('Loss (mse)')
plt.legend()

plt.show()

# %%
# You can use the code created above to type the next cell code

# %% [markdown]
# _________________![image.png](attachment:02c09230-3aba-4573-8e73-6abd5e03c12a.png)

# %%
forecast =[]
periods = 12 
first_eval_batch= scaled_full_data[-length:]
current_batch=first_eval_batch.reshape((1, length, n_features))
for i in range(periods):
    current_pred=model.predict(current_batch)[0]
    forecast.append(current_pred)
    current_batch=np.append(current_batch[:,1:,:],[[current_pred]],axis=1)
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 61ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 78ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 79ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 61ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 68ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 97ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 105ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 90ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 63ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 72ms/step

# %%
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 711ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 87ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 96ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 82ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 87ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 96ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 98ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 85ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 97ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 109ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 169ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 93ms/step

# %% [markdown]
# ______________________![image.png](attachment:3072f528-93a6-486e-b230-a376ae174ea2.png)

# %%
forecast=scaler.inverse_transform(forecast)
forecast
# Out:
# array([[21085.67682713],
#        [24126.50301254],
#        [25322.09420973],
#        [25303.30180895],
#        [27575.58817852],
#        [25798.06324768],
#        [26369.13388193],
#        [28193.00368726],
#        [25645.61449063],
#        [25929.16422021],
#        [28910.97300255],
#        [41049.32415009]])

# %%
# Out:
# array([[18620.61448288],
#        [20206.91406763],
#        [22167.73939276],
#        [21757.40348327],
#        [23828.92585731],
#        [22448.01823115],
#        [22479.73978627],
#        [23555.70857722],
#        [21352.45454019],
#        [22294.99097872],
#        [25707.46347636],
#        [37294.23667431]])

# %% [markdown]
# ### Creating new timestamp index with pandas.

# %% [markdown]
# <html> <h4 style="font-style:italic; color:blue;"> Just run the 4 next cells using 'Ctrl' + 'Enter' </h4> </html>

# %%
df
# Out:
#                   Sales
# observation_date
# 1992-01-01         6938
# 1992-02-01         7524
# 1992-03-01         8475
# 1992-04-01         9401
# 1992-05-01         9558
# ...                 ...
# 2024-08-01        27215
# 2024-09-01        23088
# 2024-10-01        25318
# 2024-11-01        29762
# 2024-12-01        41199
#
# [396 rows x 1 columns]

# %%
forecast_index = pd.date_range(start='2025-01-01',periods=periods,freq='MS')

# %%
forecast_df = pd.DataFrame(data=forecast,index=forecast_index,
                           columns=['Forecast'])

# %%
forecast_df
# Out:
#                 Forecast
# 2025-01-01  21085.676827
# 2025-02-01  24126.503013
# 2025-03-01  25322.094210
# 2025-04-01  25303.301809
# 2025-05-01  27575.588179
# 2025-06-01  25798.063248
# 2025-07-01  26369.133882
# 2025-08-01  28193.003687
# 2025-09-01  25645.614491
# 2025-10-01  25929.164220
# 2025-11-01  28910.973003
# 2025-12-01  41049.324150

# %% [markdown]
# __________________![image.png](attachment:a493f4a8-33ea-440d-ad45-8d5a273f8dfb.png)

# %%
df.plot(figsize=(8,5))
plt.show();

# %% [markdown]
# ____________________![image.png](attachment:f61a4158-30b1-457d-9aaa-2945b1ec8833.png)

# %%
forecast_df.plot(figsize=(8,5))
plt.show();

# %% [markdown]
# ### Joining pandas plots
#
# https://stackoverflow.com/questions/13872533/plot-different-dataframes-in-the-same-figure

# %% [markdown]
# ________________________![image.png](attachment:1ad9f420-c284-4442-8931-039f36b4390a.png)

# %%
ax = df.plot(figsize=(13,8))
forecast_df.plot(ax=ax)
plt.show();

# %% [markdown]
# _______![image.png](attachment:5611350d-0e2b-4867-9b54-de812a2abd8a.png)

# %%
ax = df.plot(figsize=(8,5))
forecast_df.plot(ax=ax)
plt.xlim('2023-01-01','2026-01-01')
plt.show();

# %% [markdown]
# ### Cecking Forecast for last 12 months

# %% [markdown]
# <html> <h4 style="font-style:italic; color:blue;"> Just run the 3 next cells using 'Ctrl' + 'Enter' </h4> </html>

# %%
forecast_index = pd.date_range(start='2024-01-01', periods=periods, freq='MS')
forecast_index
# Out:
# DatetimeIndex(['2024-01-01', '2024-02-01', '2024-03-01', '2024-04-01',
#                '2024-05-01', '2024-06-01', '2024-07-01', '2024-08-01',
#                '2024-09-01', '2024-10-01', '2024-11-01', '2024-12-01'],
#               dtype='datetime64[ns]', freq='MS')

# %%
forecast_df = pd.DataFrame(data=forecast, index=forecast_index,
                           columns=['Forecast'])

# %%
ax = df.plot(figsize=(12,6))
forecast_df.plot(ax=ax)
plt.xlim('2020-01-01','2025-01-01')
plt.show();

# %% [markdown]
# <html> <h2 style="font-style:bold; color:red;"> Lab Logbook requirements </h2> </html>
#
# ### 1. Plot of the 2nd model's summary
#
# ### 2. Copy your early-stop code and history_2 fit-training-process
#
# ### 3. Please record the plot of validation and test loss of history_2.
#
# ### 4. Based on this analysis, determine the optimal number of epochs for training your model.

# %% [markdown]
# ### Try the same example with a LSTM and GRU! (Optional)
# Hint: Use LSTM instead of SimpleRNN!
